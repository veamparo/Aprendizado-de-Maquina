# %% [markdown]
# Aprendizado de Maquina modelos de classificação

# %% [markdown]
# Objetivo apreender alguns modelos de classificação que fazem parte de um conjuto de técnicas de Aprendizado de Maquina supervisionado.
#
# Usaremos a base com as informações idade e valor da conta corrente de clientes de um banco, para identificar se o cliente é um bom ou ruim pagador, objetivo é prever o risco de crédito oferecido pelo banco. Modelo usado para prever o risco Classificador KNN (k-nearest neighbors)

# %% [markdown]
# O classificador KNN está presente no pacote sklearn no caminho sklearn.neighbors e é identificado como KNeighborsClassifier.

# %% [markdown]
# https://github.com/ronaldolagepessoa/machine-learning/blob/master/classification_01.ipynb

# %%
# Importando as bibliotecas
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\Documents\GitHub\Aprendizado-de-Maquina\Dados\exemplo2.csv")
df
# Out:
#           idade  conta_corrente risco
# 0     21.257389      783.127911  ruim
# 1     21.766573      979.747521   bom
# 2     25.321033     1065.328054  ruim
# 3     23.919268     1195.758078   bom
# 4     21.805298     1083.764450   bom
# ...         ...             ...   ...
# 2495  63.840703     2847.204903  ruim
# 2496  57.367341     3238.149058   bom
# 2497  65.785408     2603.620751  ruim
# 2498  52.944838     2985.948214  ruim
# 2499  52.426936     3673.193947   bom
#
# [2500 rows x 3 columns]

# %% [markdown]
# Abaixo, temos a gráfico de dispersão comparando a idade e valor em conta para cada tipo de risco.

# %%
plt.figure(figsize=(15,8))
plt.scatter()

# %% [markdown]
# plt.figure(figsize=(15, 8))
# plt.scatter(df[df.risco == 'ruim'].idade, df[df.risco == 'ruim'].conta_corrente)
# plt.scatter(df[df.risco == 'bom'].idade, df[df.risco == 'bom'].conta_corrente)
# plt.xlabel('idade')
# plt.ylabel('conta corrente')
# plt.legend(['ruim', 'bom'])
