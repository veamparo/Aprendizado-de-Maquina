# %% [markdown]
# Projeto de Machine learning
#
# Etapas:
# 1. Entendimento do problema
# 2. Selecionar dados
# 3. Análise Exploratória dos dados -AED

# %%
#Entender as principais etapas de um modelo de Machine Learning
